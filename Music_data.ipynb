# %% [markdown]
# <a href="https://colab.research.google.com/github/lujio20/EEG-RealTime-Signal-Analysis/blob/main/Music_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


base_path = "/content/drive/MyDrive/NeuroGift_Project/Raw_Data_Music/"

print("🔄 جاري قراءة ملفات الموسيقى...")

try:
    df_up = pd.read_csv(base_path + "MEFAR_UP.csv")
    df_mid = pd.read_csv(base_path + "MEFAR_MID.csv")
    df_down = pd.read_csv(base_path + "MEFAR_DOWN.csv")

    # دمجهم في جدول واحد كبير
    df_music_raw = pd.concat([df_up, df_mid, df_down], ignore_index=True)
    print(f"✅ تم تحميل ودمج الملفات! عدد الصفوف الكلي: {len(df_music_raw)}")

except FileNotFoundError:
    print("❌ خطأ: لم يتم العثور على الملفات! تأكدي أنك رفعتيها في المجلد الصحيح (Raw_Data_Music) أو عدلي المسار في الكود.")


processed_data = pd.DataFrame()

channels = ['Fp1', 'Fp2', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2']

print("⚙️ جاري معالجة البيانات وتوحيد القنوات...")

for ch in channels:

    processed_data[f"{ch}_Alpha"] = df_music_raw['Alpha1']
    processed_data[f"{ch}_Beta"] = df_music_raw['Beta1']


processed_data['Label'] = 'Musical'

# 5. الحفظ النهائي في الدرايف
save_path =  "/content/drive/MyDrive/NeuroGift_Project/Processed_Data/Musical_Processed.csv"
processed_data.to_csv(save_path, index=False)

print("-" * 30)
print(f"🎉 تم بنجاح! تم حفظ الملف النهائي: Musical_Processed.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd


base_path = "/content/drive/MyDrive/NeuroGift_Project/Raw_Data_Music/"

print("🔄 جاري قراءة ملفات الموسيقى...")

try:
    df_up = pd.read_csv(base_path + "MEFAR_UP.csv")
    df_mid = pd.read_csv(base_path + "MEFAR_MID.csv")
    df_down = pd.read_csv(base_path + "MEFAR_DOWN.csv")


    df_music_raw = pd.concat([df_up, df_mid, df_down], ignore_index=True)
    print(f"✅ تم تحميل ودمج الملفات! عدد الصفوف الكلي: {len(df_music_raw)}")

except FileNotFoundError:
    print("❌ خطأ: لم يتم العثور على الملفات! تأكدي أنك رفعتيها في المجلد الصحيح (Raw_Data_Music) أو عدلي المسار في الكود.")



processed_data = pd.DataFrame()

# قائمة القنوات القياسية لمشروعنا
channels = ['Fp1', 'Fp2', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2']

print("⚙️ جاري معالجة البيانات وتوحيد القنوات...")

for ch in channels:
    processed_data[f"{ch}_Alpha"] = df_music_raw['Alpha1']
    processed_data[f"{ch}_Beta"] = df_music_raw['Beta1']

processed_data['Label'] = 'Musical'

# 5. الحفظ النهائي في الدرايف
save_path =  "/content/drive/MyDrive/NeuroGift_Project/Processed_Data/Musical_Processed.csv"
processed_data.to_csv(save_path, index=False)

print("-" * 30)
print(f"🎉 تم بنجاح! تم حفظ الملف النهائي: Musical_Processed.csv")
